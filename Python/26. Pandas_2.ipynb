# %%
import pandas as pd

# %%
df = pd.read_csv("F:\\sales_data_final.csv")

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %% [markdown]
# ### LOC and ILOC

# %%
df.loc[[2,5,6,7,8,9]]
# Out:
#         order_id order_date ship_date       ship_mode     customer_name  \
# 2   HU-2011-1220   1/1/2011  1/5/2011    Second Class     Annie Thurman
# 5  IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 6   CA-2011-1510   1/2/2011  1/6/2011  Standard Class   Magdelene Morse
# 7  IN-2011-79397   1/3/2011  1/3/2011        Same Day       Kean Nguyen
# 8  ID-2011-80230   1/3/2011  1/9/2011  Standard Class      Ken Lonsdale
# 9   IZ-2011-4680   1/3/2011  1/7/2011  Standard Class  Lindsay Williams
#
#      segment            state      country  market   region  ...  \
# 2   Consumer         Budapest      Hungary    EMEA     EMEA  ...
# 5   Consumer  New South Wales    Australia    APAC  Oceania  ...
# 6   Consumer          Ontario       Canada  Canada   Canada  ...
# 7  Corporate  New South Wales    Australia    APAC  Oceania  ...
# 8   Consumer         Auckland  New Zealand    APAC  Oceania  ...
# 9  Corporate           Ninawa         Iraq    EMEA     EMEA  ...
#
# ...

# %%
df.loc[2:20:3]
# Out:
#          order_id order_date ship_date       ship_mode  customer_name  \
# 2    HU-2011-1220   1/1/2011  1/5/2011    Second Class  Annie Thurman
# 5   IN-2011-47883   1/1/2011  1/8/2011  Standard Class    Joseph Holt
# 8   ID-2011-80230   1/3/2011  1/9/2011  Standard Class   Ken Lonsdale
# 11  IN-2011-65159   1/3/2011  1/7/2011    Second Class   Larry Blacks
# 14  ID-2011-80230   1/3/2011  1/9/2011  Standard Class   Ken Lonsdale
# 17  ID-2011-80230   1/3/2011  1/9/2011  Standard Class   Ken Lonsdale
# 20  IN-2011-79397   1/3/2011  1/3/2011        Same Day    Kean Nguyen
#
#       segment             state      country market          region  ...  \
# 2    Consumer          Budapest      Hungary   EMEA            EMEA  ...
# 5    Consumer   New South Wales    Australia   APAC         Oceania  ...
# 8    Consumer          Auckland  New Zealand   APAC         Oceania  ...
# 11   Consumer  National Capital  Philippines   APAC  Southeast Asia  ...
# ...

# %%
df.loc[2:3, ["segment","region" ]]
# Out:
#        segment region
# 2     Consumer   EMEA
# 3  Home Office  North

# %%
df.iloc[2:4, 5:8]
# Out:
#        segment      state  country
# 2     Consumer   Budapest  Hungary
# 3  Home Office  Stockholm   Sweden

# %%
df.order_date
# Out:
# 0          1/1/2011
# 1          1/1/2011
# 2          1/1/2011
# 3          1/1/2011
# 4          1/1/2011
#             ...
# 51285    12/31/2014
# 51286    12/31/2014
# 51287    12/31/2014
# 51288    12/31/2014
# 51289    12/31/2014
# Name: order_date, Length: 51290, dtype: object

# %%
date =pd.to_datetime(df['order_date'])

# %%
date
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
df['converted_order_date'] = pd.to_datetime(df['order_date'])

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.dtypes
# Out:
# order_id                        object
# order_date                      object
# ship_date                       object
# ship_mode                       object
# customer_name                   object
# segment                         object
# state                           object
# country                         object
# market                          object
# region                          object
# product_id                      object
# category                        object
# sub_category                    object
# product_name                    object
# sales                           object
# quantity                         int64
# discount                       float64
# profit                         float64
# shipping_cost                  float64
# order_priority                  object
# year                             int64
# converted_order_date    datetime64[ns]
# dtype: object

# %%
df['order_date_year'] = df['converted_order_date'].dt.year

# %%
df['order_date_year']
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 51285    2014
# 51286    2014
# 51287    2014
# 51288    2014
# 51289    2014
# Name: order_date_year, Length: 51290, dtype: int32

# %%
df['order_date_month'] = df['converted_order_date'].dt.month

# %%
df['order_date_month']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 51285    12
# 51286    12
# 51287    12
# 51288    12
# 51289    12
# Name: order_date_month, Length: 51290, dtype: int32

# %%
df['order_date_week'] = df['converted_order_date'].dt.isocalendar().week

# %%
df['order_date_week']
# Out:
# 0        52
# 1        52
# 2        52
# 3        52
# 4        52
#          ..
# 51285     1
# 51286     1
# 51287     1
# 51288     1
# 51289     1
# Name: order_date_week, Length: 51290, dtype: UInt32

# %%
df['order_date_day'] = df['converted_order_date'].dt.day

# %%
df['order_date_day']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 51285    31
# 51286    31
# 51287    31
# 51288    31
# 51289    31
# Name: order_date_day, Length: 51290, dtype: int32

# %%
df[df['order_date_year'] == 2014 ]["customer_name"]
# Out:
# 33759         Fred Harton
# 33760         Kean Nguyen
# 33761        Alan Shonely
# 33762        Duane Benoit
# 33763       Kelly Lampkin
#                ...
# 51285          Erica Bern
# 51286           Liz Preis
# 51287    Charlotte Melton
# 51288       Tamara Dahlen
# 51289       Jill Matthias
# Name: customer_name, Length: 17531, dtype: object

# %%
df[df['order_date_month'] ==10 ]["customer_name"]
# Out:
# 5822          Ann Chong
# 5823         Evan Henry
# 5824        Greg Hansen
# 5825       Art Ferguson
# 5826          Ann Chong
#               ...
# 46985      Jamie Kunitz
# 46986     Mick Crebagga
# 46987    Michelle Moray
# 46988         Jane Waco
# 46989       Gary McGarr
# Name: customer_name, Length: 4490, dtype: object

# %%
df2 = df.copy()

# %%
df2
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df3 = df[df.dtypes[(df.dtypes == 'float64') | ( df.dtypes == 'int64')].index]

# %%
df3
# Out:
#        quantity  discount    profit  shipping_cost  year
# 0             2       0.0  106.1400          35.46  2011
# 1             3       0.1   36.0360           9.72  2011
# 2             4       0.0   29.6400           8.17  2011
# 3             3       0.5  -26.0550           4.82  2011
# 4             5       0.1   37.7700           4.70  2011
# ...         ...       ...       ...            ...   ...
# 51285         2       0.2    4.5188           0.89  2014
# 51286         1       0.0    0.4200           0.49  2014
# 51287         3       0.0   12.3600           0.35  2014
# 51288         1       0.0    0.5600           0.20  2014
# 51289         3       0.2   -0.6048           0.17  2014
#
# [51290 rows x 5 columns]

# %%
df3[df3 > 10]
# Out:
#        quantity  discount   profit  shipping_cost  year
# 0           NaN       NaN  106.140          35.46  2011
# 1           NaN       NaN   36.036            NaN  2011
# 2           NaN       NaN   29.640            NaN  2011
# 3           NaN       NaN      NaN            NaN  2011
# 4           NaN       NaN   37.770            NaN  2011
# ...         ...       ...      ...            ...   ...
# 51285       NaN       NaN      NaN            NaN  2014
# 51286       NaN       NaN      NaN            NaN  2014
# 51287       NaN       NaN   12.360            NaN  2014
# 51288       NaN       NaN      NaN            NaN  2014
# 51289       NaN       NaN      NaN            NaN  2014
#
# [51290 rows x 5 columns]

# %%
df4 = df3[df3 > 10]

# %%
df4.dropna()
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, year]
# Index: []

# %%
df4
# Out:
#        quantity  discount   profit  shipping_cost  year
# 0           NaN       NaN  106.140          35.46  2011
# 1           NaN       NaN   36.036            NaN  2011
# 2           NaN       NaN   29.640            NaN  2011
# 3           NaN       NaN      NaN            NaN  2011
# 4           NaN       NaN   37.770            NaN  2011
# ...         ...       ...      ...            ...   ...
# 51285       NaN       NaN      NaN            NaN  2014
# 51286       NaN       NaN      NaN            NaN  2014
# 51287       NaN       NaN   12.360            NaN  2014
# 51288       NaN       NaN      NaN            NaN  2014
# 51289       NaN       NaN      NaN            NaN  2014
#
# [51290 rows x 5 columns]

# %%
df4.dropna(thresh=3)
# Out:
#        quantity  discount   profit  shipping_cost  year
# 0           NaN       NaN  106.140          35.46  2011
# 7           NaN       NaN  110.412         125.32  2011
# 9           NaN       NaN  253.320          81.26  2011
# 12          NaN       NaN  290.430          12.56  2011
# 13          NaN       NaN   50.130          10.40  2011
# ...         ...       ...      ...            ...   ...
# 51251       NaN       NaN   40.752          12.75  2014
# 51252       NaN       NaN  166.440          11.71  2014
# 51253       NaN       NaN   20.160          11.50  2014
# 51254       NaN       NaN   17.580          10.93  2014
# 51258      12.0       NaN   55.080            NaN  2014
#
# [16122 rows x 5 columns]

# %%
df4.fillna(value=4)
# Out:
#        quantity  discount   profit  shipping_cost  year
# 0           4.0       4.0  106.140          35.46  2011
# 1           4.0       4.0   36.036           4.00  2011
# 2           4.0       4.0   29.640           4.00  2011
# 3           4.0       4.0    4.000           4.00  2011
# 4           4.0       4.0   37.770           4.00  2011
# ...         ...       ...      ...            ...   ...
# 51285       4.0       4.0    4.000           4.00  2014
# 51286       4.0       4.0    4.000           4.00  2014
# 51287       4.0       4.0   12.360           4.00  2014
# 51288       4.0       4.0    4.000           4.00  2014
# 51289       4.0       4.0    4.000           4.00  2014
#
# [51290 rows x 5 columns]

# %%
df4.fillna(value=df4['profit'].mean())
# Out:
#        quantity  discount     profit  shipping_cost  year
# 0      93.48771  93.48771  106.14000       35.46000  2011
# 1      93.48771  93.48771   36.03600       93.48771  2011
# 2      93.48771  93.48771   29.64000       93.48771  2011
# 3      93.48771  93.48771   93.48771       93.48771  2011
# 4      93.48771  93.48771   37.77000       93.48771  2011
# ...         ...       ...        ...            ...   ...
# 51285  93.48771  93.48771   93.48771       93.48771  2014
# 51286  93.48771  93.48771   93.48771       93.48771  2014
# 51287  93.48771  93.48771   12.36000       93.48771  2014
# 51288  93.48771  93.48771   93.48771       93.48771  2014
# 51289  93.48771  93.48771   93.48771       93.48771  2014
#
# [51290 rows x 5 columns]

# %% [markdown]
# ### Groupby

# %%
df.groupby('order_date_year')["profit"].min()
# Out:
# order_date_year
# 2011   -3701.8928
# 2012   -2639.9912
# 2013   -6599.9780
# 2014   -3839.9904
# Name: profit, dtype: float64

# %%
df.groupby('order_date_year')["profit"].max()
# Out:
# order_date_year
# 2011    4630.4755
# 2012    3177.4750
# 2013    8399.9760
# 2014    6719.9808
# Name: profit, dtype: float64

# %%
df.groupby("discount")["profit"].max()
# Out:
# discount
# 0.000    8399.97600
# 0.002     872.82816
# 0.070    1554.43200
# 0.100    2316.51000
# 0.150    1517.71200
# 0.170     946.63380
# 0.200    3919.98880
# 0.202     317.78720
# 0.250     822.66000
# 0.270     368.25600
# 0.300     726.82500
# 0.320      -6.01960
# 0.350     515.75250
# 0.370     139.64760
# 0.400    1119.99680
# 0.402      61.71600
# 0.450      18.03750
# 0.470      35.81760
# 0.500       0.00000
# 0.550     -70.39950
# 0.570     -72.60720
# 0.600      -0.70200
# 0.602     -25.92000
# 0.650     -74.83800
# 0.700      -0.59640
# 0.800      -0.94520
# 0.850   -1144.11600
# Name: profit, dtype: float64

# %%
df.groupby( "segment")["profit"].max()
# Out:
# segment
# Consumer       6719.9808
# Corporate      8399.9760
# Home Office    3919.9888
# Name: profit, dtype: float64

# %%
df.groupby('customer_name')['discount'].mean()
# Out:
# customer_name
# Aaron Bergman         0.110112
# Aaron Hawkins         0.160929
# Aaron Smayling        0.167667
# Adam Bellavance       0.131765
# Adam Hart             0.093238
#                         ...
# Xylona Preis          0.084754
# Yana Sorensen         0.070968
# Yoseph Carroll        0.070000
# Zuschuss Carroll      0.221318
# Zuschuss Donatelli    0.115778
# Name: discount, Length: 795, dtype: float64

# %%
df['sales'].unique()
# Out:
# array(['408', '120', '66', ..., '1,763', '1,821', '1,831'], dtype=object)

# %%
df['sales'] = pd.to_numeric(df['sales'], errors='coerce').astype('Int64')

# %%
df['sales']
# Out:
# 0        408
# 1        120
# 2         66
# 3         45
# 4        114
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51290, dtype: Int64

# %%
df['order_date_day'] = pd.to_numeric(df['sales'], errors='coerce').astype('Int64')

# %%
df.dtypes
# Out:
# order_id                        object
# order_date                      object
# ship_date                       object
# ship_mode                       object
# customer_name                   object
# segment                         object
# state                           object
# country                         object
# market                          object
# region                          object
# product_id                      object
# category                        object
# sub_category                    object
# product_name                    object
# sales                            Int64
# quantity                         int64
# discount                       float64
# profit                         float64
# shipping_cost                  float64
# order_priority                  object
# year                             int64
# converted_order_date    datetime64[ns]
# order_date_year                  int32
# order_date_month                 int32
# ...

# %%
df.dtypes
# Out:
# order_id                        object
# order_date                      object
# ship_date                       object
# ship_mode                       object
# customer_name                   object
# segment                         object
# state                           object
# country                         object
# market                          object
# region                          object
# product_id                      object
# category                        object
# sub_category                    object
# product_name                    object
# sales                            Int64
# quantity                         int64
# discount                       float64
# profit                         float64
# shipping_cost                  float64
# order_priority                  object
# year                             int64
# converted_order_date    datetime64[ns]
# order_date_year                  int32
# order_date_month                 int32
# ...

# %%
df.order_id
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df["country"].unique()
# Out:
# array(['Algeria', 'Australia', 'Hungary', 'Sweden', 'Canada',
#        'New Zealand', 'Iraq', 'Philippines', 'United Kingdom', 'Malaysia',
#        'Guatemala', 'Iran', 'Thailand', 'Tanzania', 'Brazil', 'Mexico',
#        'Cuba', 'France', 'United States', 'Japan', 'Sudan', 'Taiwan',
#        'Indonesia', 'Vietnam', 'Angola', 'China', 'Mozambique', 'Lebanon',
#        'Singapore', 'Netherlands', 'Nigeria', 'Egypt', 'Venezuela',
#        'South Africa', 'Spain', 'India', 'Turkey', 'Austria', 'Italy',
#        'Germany', 'Nicaragua', 'Dominican Republic', 'El Salvador',
#        'Denmark', 'Saudi Arabia', 'Zambia', 'Myanmar (Burma)', 'Russia',
#        'Mongolia', 'Belgium', 'Kenya', 'Colombia', 'Estonia',
#        'Madagascar', 'Portugal', 'Morocco', 'Sierra Leone', 'Norway',
#        'Central African Republic', 'Czech Republic', 'Benin',
#        'Bangladesh', 'Panama', 'Chile', 'South Korea', 'Switzerland',
#        'Moldova', 'Uganda', 'Zimbabwe', 'Niger', 'Senegal', 'Hong Kong',
# ...

# %%
df['country'] = df.country.str.replace('Myanmar (Burma)' , "Myanmar").astype(str)

# %%
df['country'].unique()
# Out:
# array(['Algeria', 'Australia', 'Hungary', 'Sweden', 'Canada',
#        'New Zealand', 'Iraq', 'Philippines', 'United Kingdom', 'Malaysia',
#        'Guatemala', 'Iran', 'Thailand', 'Tanzania', 'Brazil', 'Mexico',
#        'Cuba', 'France', 'United States', 'Japan', 'Sudan', 'Taiwan',
#        'Indonesia', 'Vietnam', 'Angola', 'China', 'Mozambique', 'Lebanon',
#        'Singapore', 'Netherlands', 'Nigeria', 'Egypt', 'Venezuela',
#        'South Africa', 'Spain', 'India', 'Turkey', 'Austria', 'Italy',
#        'Germany', 'Nicaragua', 'Dominican Republic', 'El Salvador',
#        'Denmark', 'Saudi Arabia', 'Zambia', 'Myanmar', 'Russia',
#        'Mongolia', 'Belgium', 'Kenya', 'Colombia', 'Estonia',
#        'Madagascar', 'Portugal', 'Morocco', 'Sierra Leone', 'Norway',
#        'Central African Republic', 'Czech Republic', 'Benin',
#        'Bangladesh', 'Panama', 'Chile', 'South Korea', 'Switzerland',
#        'Moldova', 'Uganda', 'Zimbabwe', 'Niger', 'Senegal', 'Hong Kong',
# ...

# %%
df['country'] = df.country.str.replace("H" , "a").astype(str)

# %%
df['country'].unique()
# Out:
# array(['algeria', 'australia', 'aungary', 'Sweden', 'Canada',
#        'New Zealand', 'Iraq', 'Philippines', 'United Kingdom', 'Malaysia',
#        'Guatemala', 'Iran', 'Thailand', 'Tanzania', 'Brazil', 'Mexico',
#        'Cuba', 'France', 'United States', 'Japan', 'Sudan', 'Taiwan',
#        'Indonesia', 'Vietnam', 'angola', 'China', 'Mozambique', 'Lebanon',
#        'Singapore', 'Netherlands', 'Nigeria', 'Egypt', 'Venezuela',
#        'South africa', 'Spain', 'India', 'Turkey', 'austria', 'Italy',
#        'Germany', 'Nicaragua', 'Dominican Republic', 'El Salvador',
#        'Denmark', 'Saudi arabia', 'Zambia', 'Myanmar', 'Russia',
#        'Mongolia', 'Belgium', 'Kenya', 'Colombia', 'Estonia',
#        'Madagascar', 'Portugal', 'Morocco', 'Sierra Leone', 'Norway',
#        'Central african Republic', 'Czech Republic', 'Benin',
#        'Bangladesh', 'Panama', 'Chile', 'South Korea', 'Switzerland',
#        'Moldova', 'Uganda', 'Zimbabwe', 'Niger', 'Senegal', 'aong Kong',
# ...
