# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("F:\sales_data_final.csv")

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Dra        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
df.sample(10)
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 5420    MX-2011-102127   9/20/2011   9/24/2011    Second Class
# 42032  ES-2014-3174376    8/7/2014   8/12/2014  Standard Class
# 30199    ID-2013-13625  10/22/2013  10/28/2013  Standard Class
# 31729  ES-2013-1532910  11/22/2013  11/29/2013  Standard Class
# 7975      TU-2011-8770   12/8/2011  12/11/2011     First Class
# 29289     NI-2013-6720   9/26/2013   10/2/2013  Standard Class
# 31583   MX-2013-163580  11/19/2013  11/25/2013  Standard Class
# 7571    CA-2011-168984  11/26/2011   12/2/2011  Standard Class
# 5139      LY-2011-4410   9/12/2011   9/17/2011  Standard Class
# 36883   MX-2014-148719   4/11/2014   4/14/2014     First Class
#
#             customer_name      segment             state        country  \
# 5420   Christine Kargatis  Home Office            Granma           Cuba
# 42032   Michelle Lonsdale    Corporate            Madrid          Spain
# ...

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.shape
# Out:
# (51290, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.describe(include="all").T
# Out:
#                   count unique              top   freq         mean  \
# order_id          51290  25035   CA-2014-100111     14          NaN
# order_date        51290   1430        6/18/2014    135          NaN
# ship_date         51290   1464       11/22/2014    130          NaN
# ship_mode         51290      4   Standard Class  30775          NaN
# customer_name     51290    795  Muhammed Yedwab    108          NaN
# segment           51290      3         Consumer  26518          NaN
# state             51290   1094       California   2001          NaN
# country           51290    147    United States   9994          NaN
# market            51290      7             APAC  11002          NaN
# region            51290     13          Central  11117          NaN
# product_id        51290  10292  OFF-AR-10003651     35          NaN
# category          51290      3  Office Supplies  31273          NaN
# sub_category      51290     17          Binders   6152          NaN
# ...

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
df.profit
# Out:
# 0        106.1400
# 1         36.0360
# 2         29.6400
# 3        -26.0550
# 4         37.7700
#            ...
# 51285      4.5188
# 51286      0.4200
# 51287     12.3600
# 51288      0.5600
# 51289     -0.6048
# Name: profit, Length: 51290, dtype: float64

# %%
type(df.profit)
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.sub_category
# Out:
# 0            Storage
# 1           Supplies
# 2            Storage
# 3              Paper
# 4        Furnishings
#             ...
# 51285        Binders
# 51286        Binders
# 51287         Labels
# 51288         Labels
# 51289      Fasteners
# Name: sub_category, Length: 51290, dtype: object

# %%
df["sub_category", "profit"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('sub_category', 'profit')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df["sub_category"]["profit"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df["sub_category"]["profit"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# ...

# %%
df[["sales", "sub_category", "profit" ]]
# Out:
#       sales sub_category    profit
# 0       408      Storage  106.1400
# 1       120     Supplies   36.0360
# 2        66      Storage   29.6400
# 3        45        Paper  -26.0550
# 4       114  Furnishings   37.7700
# ...     ...          ...       ...
# 51285    14      Binders    4.5188
# 51286     4      Binders    0.4200
# 51287    26       Labels   12.3600
# 51288     7       Labels    0.5600
# 51289     3    Fasteners   -0.6048
#
# [51290 rows x 3 columns]

# %%
df["profit"].mean()
# Out:
# 28.64173954533047

# %%
df["profit"].min()
# Out:
# -6599.978

# %%
df['region'].unique()
# Out:
# array(['Africa', 'Oceania', 'EMEA', 'North', 'Canada', 'Southeast Asia',
#        'Central', 'South', 'Caribbean', 'North Asia', 'East', 'West',
#        'Central Asia'], dtype=object)

# %%
df['region'].value_counts(ascending= True)
# Out:
# region
# Canada              384
# Caribbean          1690
# Central Asia       2048
# North Asia         2338
# East               2848
# Southeast Asia     3129
# West               3203
# Oceania            3487
# Africa             4587
# North              4785
# EMEA               5029
# South              6645
# Central           11117
# Name: count, dtype: int64

# %%
df['region'].isnull().sum()
# Out:
# 0

# %%
df["new_col"] = "amit"

# %%
df.drop("new_col", axis=1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.drop("new_col", axis=1, inplace= True)

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df["Cost_to_company"] = df["discount"] + df["shipping_cost"]

# %%
df[["discount", "shipping_cost", "Cost_to_company"]]
# Out:
#        discount  shipping_cost  Cost_to_company
# 0           0.0          35.46            35.46
# 1           0.1           9.72             9.82
# 2           0.0           8.17             8.17
# 3           0.5           4.82             5.32
# 4           0.1           4.70             4.80
# ...         ...            ...              ...
# 51285       0.2           0.89             1.09
# 51286       0.0           0.49             0.49
# 51287       0.0           0.35             0.35
# 51288       0.0           0.20             0.20
# 51289       0.2           0.17             0.37
#
# [51290 rows x 3 columns]

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df[df["discount"]>0.8]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 12082  IT-2012-2675422   5/31/2012    6/2/2012    Second Class
# 18023  IT-2012-5588535  11/16/2012  11/21/2012  Standard Class
#
#           customer_name      segment         state  country market   region  \
# 12082   Benjamin Farhat  Home Office  Lower Saxony  Germany     EU  Central
# 18023  Mitch Willingham    Corporate  Lower Saxony  Germany     EU  Central
#
#        ... sub_category                              product_name sales  \
# 12082  ...       Tables   Bevis Conference Table, Fully Assembled   555
# 18023  ...       Tables  Chromcraft Coffee Table, Fully Assembled   242
#
#       quantity discount    profit  shipping_cost  order_priority  year  \
# 12082        4     0.85 -1924.542          62.75            High  2012
# 18023        6     0.85 -1144.116          23.38            High  2012
#
#       Cost_to_company
# 12082           63.60
# 18023           24.23
#
# [2 rows x 22 columns]

# %%
df[df["discount"]>0.8]["profit"]
# Out:
# 12082   -1924.542
# 18023   -1144.116
# Name: profit, dtype: float64

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'new_col'],
#       dtype='object')
